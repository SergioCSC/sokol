# %% [markdown]
# <a href="https://colab.research.google.com/github/SergioCSC/sokol/blob/master/huffman/test_MinHeap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from draw_tree import draw_tree
from MinHeap import MinHeap

import random

def generate_random_array(size: int, min_value: int = 1, max_value: int = 100) -> list:
    """Generate a random array of integers"""
    return [random.randint(min_value, max_value) for _ in range(size)]

arr = generate_random_array(10)
min_heap = MinHeap()
for value in arr:
    print(value, end=' ')
    min_heap.push(value)

adjacency_dict = min_heap.get_adjacency_dict(0)
print(f"\nAdjacency dictionary: {adjacency_dict}")
draw_tree(adjacency_dict)

print()
while value := min_heap.pop():
    print(value, end=' ')
# Out:
# 13 25 55 92 28 3 100 52 92 62
# Adjacency dictionary: {'0\n3': ('1\n25', '2\n13'), '1\n25': ('3\n52', '4\n28'), '3\n52': ('7\n92', '8\n92'), '4\n28': ('9\n62',), '2\n13': ('5\n55', '6\n100')}
# 3 13 25 28 52 55 62 92 92 100
